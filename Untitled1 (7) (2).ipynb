# %%
import pandas as pd 
import numpy as np

# %%
df= pd.read_csv('oceania_covid.csv')
df.head(10)
# Out:
#        Country/Other  Total Cases  Total Deaths  Total Recovered  \
# 0          Australia      3293565          5311        3030616.0
# 1               Fiji        63999           834          62008.0
# 2   French Polynesia        67651           641              NaN
# 3           Kiribati         2953            11           2241.0
# 4      New Caledonia        55502           301          47969.0
# 5        New Zealand       166098            56          19263.0
# 6              Palau         3823             6           3313.0
# 7   Papua New Guinea        41335           638          39714.0
# 8    Solomon Islands         7258           106           1761.0
# 9  Wallis and Futuna          454             7            438.0
#
#    Active Cases  Tot Cases/ 1M pop  Deaths/ 1M pop  Total Tests  \
# 0      257638.0             126715             204   63752087.0
# 1        1157.0              70542             919     497559.0
# ...

# %% [markdown]
# ###Description of the dataset

# %% [markdown]
# #Esta base de datos muestra el comportamiento de la enfermedad Covid-19 en el continente de Oceanía.
# #Esta base de datos se encuentra dividida en el comportamiento de los diferentes paises del anteriormente mencionado continente.

# %%
df.columns
# Out:
# Index(['Country/Other', 'Total Cases', 'Total Deaths', 'Total Recovered',
#        'Active Cases', 'Tot Cases/ 1M pop', 'Deaths/ 1M pop', 'Total Tests',
#        'Tests/ 1M pop', 'Population'],
#       dtype='object')

# %%
## En este caso me enfocaré en las variables de Total cases, Total deaths and Total recovered

# %%
df.drop(['Tot Cases/ 1M pop','Deaths/ 1M pop','Total Tests','Tests/ 1M pop','Population',],
        axis= 1,
        inplace= True)
df.columns
# Out:
# Index(['Country/Other', 'Total Cases', 'Total Deaths', 'Total Recovered',
#        'Active Cases'],
#       dtype='object')

# %%
df.rename(columns = { 'Country/Other':'Country',},
          inplace= True
         )
df.head()
# Out:
#             Country  Total Cases  Total Deaths  Total Recovered  Active Cases
# 0         Australia      3293565          5311        3030616.0      257638.0
# 1              Fiji        63999           834          62008.0        1157.0
# 2  French Polynesia        67651           641              NaN           NaN
# 3          Kiribati         2953            11           2241.0         701.0
# 4     New Caledonia        55502           301          47969.0        7232.0

# %% [markdown]
# ## Descripcion de las variables

# %%
# Country- Is a column que representa el país donde se encuentran almacenados los datos 
# Total Cases- Representa el total de los casos de covid-19
# Total deaths - Esta columna representa la cantidad de muertes por covid-19 
# Total recovered - Esta columna representa la cantidad de pacientes recuperados por covid19 
# Active cases - Esta columna representa la cantidad de casos activos que se representan

# %% [markdown]
# ## Preguntas

# %% [markdown]
# # 1. Cual es el país que cuenta con la mayor cantidad de casos en el continente de oceanía?

# %% [markdown]
# # 2. Cual es el pais que cuenta con la mayor cantidad de muertes en el continente de oceanía?

# %% [markdown]
# # 3. Cual es el país que cuenta con mayror cantidad de pacientes recuperados de covid-19?

# %% [markdown]
# # 4. Cual es el país que cuenta con mayor cantidad de casos activos en oceanía?

# %% [markdown]
# ## Diagrama de barras representando las variables estudiadas

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
muestra.plot(kind = 'bar',
             width=0.8,
             subplots=True,
             figsize=(10,20));
